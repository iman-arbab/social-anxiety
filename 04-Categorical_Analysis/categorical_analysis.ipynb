# %% [markdown]
# 1. Fill "Therapy History"
# --> Push
# 2. Add GUI
# --> Push
# 3. Match the code with visualization code
# --> Push
# 4. About this project: (about - name - date - ...)
# 5. Write comments and manual for projects
# --> Push
# 6. Find Relationship Examples for PDF
# --> Send it in the group

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("social_anxiety_dataset.csv")

# %%
df.head()
# Out:
#     Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0  59.0   Other    Teacher          7.0                           2.4
# 1  46.0  Female    Student          5.1                           5.4
# 2  40.0   Other     Lawyer          5.1                           1.9
# 3  40.0    Male      Nurse          7.6                           0.9
# 4  26.0    Male      Other          6.7                           3.0
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                      40.0                                  5     Yes
# 1                     156.0                                 11     NaN
# 2                     570.0                                 14     Yes
# 3                     129.0                                  0      No
# 4                      64.0                                 13      No
#
#   Family History of Anxiety  Stress Level (1-10)  ...  Sweating Level (1-5)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030 entries, 0 to 2029
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1968 non-null   float64
#  1   Gender                             1911 non-null   object
#  2   Occupation                         2030 non-null   object
#  3   Sleep Hours                        1994 non-null   float64
#  4   Physical Activity (hrs/week)       2030 non-null   float64
#  5   Caffeine Intake (mg/day)           1936 non-null   float64
#  6   Alcohol Consumption (drinks/week)  2030 non-null   int64
#  7   Smoking                            1924 non-null   object
#  8   Family History of Anxiety          2030 non-null   object
#  9   Stress Level (1-10)                2030 non-null   int64
#  10  Heart Rate (bpm)                   2030 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  Sleep Hours  Physical Activity (hrs/week)  \
# count  1968.000000  1994.000000                   2030.000000
# mean     39.921748     6.424624                      2.800246
# std      13.243754     2.161544                      2.233899
# min      18.000000   -10.000000                    -10.000000
# 25%      29.000000     5.800000                      1.400000
# 50%      40.000000     6.700000                      2.800000
# 75%      51.000000     7.500000                      4.200000
# max      64.000000    11.000000                      9.200000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count               1936.000000                        2030.000000
# mean                 306.275826                           9.490148
# std                  208.012717                           6.028653
# min                    0.000000                         -10.000000
# 25%                  177.750000                           5.000000
# ...

# %%
categorical_columns = ["Gender", "Occupation", "Smoking", "Family History of Anxiety", "Dizziness", "Medication",
"Recent Major Life Event", "is_Anxious", "Therapy History"]

for column in categorical_columns:   
    print(df[column].value_counts(), "\n")
# Out:
# Gender
# Female    657
# Other     627
# Male      627
# Name: count, dtype: int64
#
# Occupation
# Student       182
# Artist        172
# Lawyer        167
# Musician      163
# Nurse         162
# Doctor        161
# Scientist     155
# Teacher       151
# Other         149
# Athlete       147
# Chef          146
# Engineer      141
# Freelancer    134
# Name: count, dtype: int64
#
# Smoking
# Yes    1020
# No      904
# Name: count, dtype: int64
#
# Family History of Anxiety
# Yes    1058
# No      972
# Name: count, dtype: int64
#
# Dizziness
# Yes    1049
# No      981
# Name: count, dtype: int64
#
# Medication
# Yes    964
# No     957
# Name: count, dtype: int64
#
# Recent Major Life Event
# Yes    1040
# No      990
# Name: count, dtype: int64
#
# is_Anxious
# 0    1820
# 1     210
# Name: count, dtype: int64
#
# Therapy History
# No previous history                   60
# Group Therapy                         54
# Cognitive Behavioral Therapy (CBT)    45
# ...

# %%
# Testing a sample for 1 column
table = pd.crosstab(df["Gender"], df["is_Anxious"])
table
# Out:
# is_Anxious    0   1
# Gender
# Female      596  61
# Male        556  71
# Other       561  66

# %%
percentages = table.apply(lambda x: x / x.sum() * 100, axis=1)
percentages
# Out:
# is_Anxious          0          1
# Gender
# Female      90.715373   9.284627
# Male        88.676236  11.323764
# Other       89.473684  10.526316

# %%
chi2, p, dof, expected = stats.chi2_contingency(table)

print("Chi-square:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
# Out:
# Chi-square: 1.4637842459690373
# p-value: 0.4809980211180541
# Degrees of freedom: 2

# %%
n = table.to_numpy().sum()
cramers_v = np.sqrt(chi2 / (n * min(table.shape[0] - 1, table.shape[1] - 1)))

print("Cramer's V:", cramers_v)
# Out:
# Cramer's V: 0.027676310279555586

# %%
# a function for 1 column

def categorical_relationship_one_column(df, col1, col2, alpha=0.05):
    print(f"Analyzing relationship between [{col1}] and [{col2}]\n")
    
    print("Statistical hypotheses:")
    print(f"H0: Variables '{col1}' and '{col2}' are completely independent (no relationship).")
    print(f"H1: Variables '{col1}' and '{col2}' are dependent.\n")
    
    contingency_table = pd.crosstab(df[col1], df[col2])
    
    chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)
    
    n = contingency_table.to_numpy().sum()
    min_dim = min(contingency_table.shape[0] - 1, contingency_table.shape[1] - 1)
    cramers_v = np.sqrt(chi2 / (n * min_dim))
    
    print("Test results:")
    print(f"Chi-square value: {chi2:.4f}")
    print(f"P-value: {p_value:.8f}")
    print(f"Degrees of freedom (DoF): {dof}")
    print(f"Cramer's V (strength of association): {cramers_v:.4f} (0 - 1)\n")
    
    print("Conclusion:")
    if p_value < alpha:
        print(f"✅ H0 is rejected (P-value < {alpha}).")
        print(f"Result: There is sufficient statistical evidence to show a significant relationship between '{col1}' and '{col2}'.")
    else:
        print(f"❌ H0 is not rejected (P-value >= {alpha}).")
        print(f"Result: '{col1}' and '{col2}' appear to be independent.")

# %%
categorical_relationship_one_column(df, 'Gender', 'Occupation')
# Out:
# Analyzing relationship between [Gender] and [Occupation]
#
# Statistical hypotheses:
# H0: Variables 'Gender' and 'Occupation' are completely independent (no relationship).
# H1: Variables 'Gender' and 'Occupation' are dependent.
#
# Test results:
# Chi-square value: 17.8506
# P-value: 0.81019491
# Degrees of freedom (DoF): 24
# Cramer's V (strength of association): 0.0683 (0 - 1)
#
# Conclusion:
# ❌ H0 is not rejected (P-value >= 0.05).
# Result: 'Gender' and 'Occupation' appear to be independent.

# %%
# a function for 2 columns

def categorical_relationship_two_columns(df, col1, val1, col2, val2, target_col, alpha=0.05):
    segments = f"'{val1} {col1}' & '{val2} {col2}'"
    print(f"Analyzing [{segments}] vs [{target_col}]")
    
    condition = (df[col1] == val1) & (df[col2] == val2)
    
    temp_groups = np.where(condition, "Target Group", "Others")
    
    contingency_table = pd.crosstab(temp_groups, df[target_col])
    print("Contingency Table:")
    print(contingency_table, "\n")

    chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)
    
    n = contingency_table.to_numpy().sum()
    min_dim = min(contingency_table.shape[0] - 1, contingency_table.shape[1] - 1)
    cramers_v = np.sqrt(chi2 / (n * min_dim))
    
    print("Test results:")
    print(f"Chi-square value: {chi2:.4f}")
    print(f"P-value: {p_value:.8f}")
    print(f"Degrees of freedom (DoF): {dof}")
    print(f"Cramer's V: {cramers_v:.4f} (0 - 1)\n")
    
    print("Conclusion:")
    if p_value < alpha:
        print(f"✅ H0 is rejected (P-value < {alpha}).")
        print(f"Result: Significant relationship between [{segments}] and ['{target_col}'].")
    else:
        print(f"❌ H0 is not rejected (P-value >= {alpha}).")
        print(f"Result: No significant relationship between [{segments}] and ['{target_col}'].")

# %%
categorical_relationship_two_columns(df, 'Medication', 'Yes', 'Recent Major Life Event', 'Yes', 'is_Anxious')
# Out:
# Analyzing ['Yes Medication' & 'Yes Recent Major Life Event'] vs [is_Anxious]
# Contingency Table:
# is_Anxious       0    1
# row_0
# Others        1403  133
# Target Group   417   77
#
# Test results:
# Chi-square value: 18.6050
# P-value: 0.00001608
# Degrees of freedom (DoF): 1
# Cramer's V: 0.0957 (0 - 1)
#
# Conclusion:
# ✅ H0 is rejected (P-value < 0.05).
# Result: Significant relationship between ['Yes Medication' & 'Yes Recent Major Life Event'] and ['is_Anxious'].
